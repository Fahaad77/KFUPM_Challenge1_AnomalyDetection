# %% [markdown]
# ## Importing Libraries

# %%
# for basic mathematics operation 
import numpy as np

# for dataframe manipulations
import pandas as pd

# for Data Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Data

# %%
data = pd.read_csv('combined_output_cleand_part_1.csv')

# %%
data.head()
# Out:
#                     timestamp  P-PDG       P-TPT     T-TPT  P-MON-CKP  \
# 0  2017-02-01 02:02:07.000000    0.0  10092110.0  119.0944  1609800.0
# 1  2017-02-01 02:02:08.000000    0.0  10092000.0  119.0944  1618206.0
# 2  2017-02-01 02:02:09.000000    0.0  10091890.0  119.0944  1626612.0
# 3  2017-02-01 02:02:10.000000    0.0  10091780.0  119.0944  1635018.0
# 4  2017-02-01 02:02:11.000000    0.0  10091670.0  119.0944  1643424.0
#
#    T-JUS-CKP  class
# 0   84.59782    0.0
# 1   84.58997    0.0
# 2   84.58213    0.0
# 3   84.57429    0.0
# 4   84.56644    0.0

# %% [markdown]
# `Convert timestamp to datetime`

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'])

# %% [markdown]
# `Extract components (Year , Month , Day , Hour , Minute , Second)`

# %%
data['year'] = data['timestamp'].dt.year
data['month'] = data['timestamp'].dt.month
data['day'] = data['timestamp'].dt.day
data['hour'] = data['timestamp'].dt.hour
data['minute'] = data['timestamp'].dt.minute
data['second'] = data['timestamp'].dt.second

# %%
data = data.drop('timestamp' , axis = 1)

# %%
data.head()
# Out:
#    P-PDG       P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP  class  year  month  day  \
# 0    0.0  10092110.0  119.0944  1609800.0   84.59782    0.0  2017      2    1
# 1    0.0  10092000.0  119.0944  1618206.0   84.58997    0.0  2017      2    1
# 2    0.0  10091890.0  119.0944  1626612.0   84.58213    0.0  2017      2    1
# 3    0.0  10091780.0  119.0944  1635018.0   84.57429    0.0  2017      2    1
# 4    0.0  10091670.0  119.0944  1643424.0   84.56644    0.0  2017      2    1
#
#    hour  minute  second
# 0     2       2       7
# 1     2       2       8
# 2     2       2       9
# 3     2       2      10
# 4     2       2      11

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# `Check Null Values`

# %%
null = pd.DataFrame({'Null Values' : data.isna().sum().sort_values(ascending=False), 'Percentage Null Values' : (data.isna().sum().sort_values(ascending=False)) / (data.shape[0]) * (100)})
null.style.background_gradient(cmap="Wistia")
# Out:
# <style type="text/css">
# #T_e6ab4_row0_col0, #T_e6ab4_row0_col1 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# #T_e6ab4_row1_col0, #T_e6ab4_row1_col1 {
#   background-color: #ffe015;
#   color: #000000;
# }
# #T_e6ab4_row2_col0, #T_e6ab4_row2_col1 {
#   background-color: #f9ed30;
#   color: #000000;
# }
# #T_e6ab4_row3_col0, #T_e6ab4_row3_col1, #T_e6ab4_row4_col0, #T_e6ab4_row4_col1, #T_e6ab4_row5_col0, #T_e6ab4_row5_col1, #T_e6ab4_row6_col0, #T_e6ab4_row6_col1, #T_e6ab4_row7_col0, #T_e6ab4_row7_col1, #T_e6ab4_row8_col0, #T_e6ab4_row8_col1, #T_e6ab4_row9_col0, #T_e6ab4_row9_col1, #T_e6ab4_row10_col0, #T_e6ab4_row10_col1, #T_e6ab4_row11_col0, #T_e6ab4_row11_col1 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_e6ab4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6ab4_level0_col0" class="col_heading level0 col0" >Null Values</th>
#       <th id="T_e6ab4_level0_col1" class="col_heading level0 col1" >Percentage Null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6ab4_level0_row0" class="row_heading level0 row0" >T-TPT</th>
#       <td id="T_e6ab4_row0_col0" class="data row0 col0" >5810976</td>
#       <td id="T_e6ab4_row0_col1" class="data row0 col1" >11.413493</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row1" class="row_heading level0 row1" >T-JUS-CKP</th>
#       <td id="T_e6ab4_row1_col0" class="data row1 col0" >1702789</td>
#       <td id="T_e6ab4_row1_col1" class="data row1 col1" >3.344493</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row2" class="row_heading level0 row2" >P-MON-CKP</th>
#       <td id="T_e6ab4_row2_col0" class="data row2 col0" >1121628</td>
#       <td id="T_e6ab4_row2_col1" class="data row2 col1" >2.203019</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row3" class="row_heading level0 row3" >P-TPT</th>
#       <td id="T_e6ab4_row3_col0" class="data row3 col0" >6184</td>
#       <td id="T_e6ab4_row3_col1" class="data row3 col1" >0.012146</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row4" class="row_heading level0 row4" >P-PDG</th>
#       <td id="T_e6ab4_row4_col0" class="data row4 col0" >5905</td>
#       <td id="T_e6ab4_row4_col1" class="data row4 col1" >0.011598</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row5" class="row_heading level0 row5" >class</th>
#       <td id="T_e6ab4_row5_col0" class="data row5 col0" >5130</td>
#       <td id="T_e6ab4_row5_col1" class="data row5 col1" >0.010076</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row6" class="row_heading level0 row6" >year</th>
#       <td id="T_e6ab4_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_e6ab4_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row7" class="row_heading level0 row7" >month</th>
#       <td id="T_e6ab4_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_e6ab4_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row8" class="row_heading level0 row8" >day</th>
#       <td id="T_e6ab4_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_e6ab4_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row9" class="row_heading level0 row9" >hour</th>
#       <td id="T_e6ab4_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_e6ab4_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row10" class="row_heading level0 row10" >minute</th>
#       <td id="T_e6ab4_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_e6ab4_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e6ab4_level0_row11" class="row_heading level0 row11" >second</th>
#       <td id="T_e6ab4_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_e6ab4_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50913215 entries, 0 to 50913214
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   P-PDG      float64
#  1   P-TPT      float64
#  2   T-TPT      float64
#  3   P-MON-CKP  float64
#  4   T-JUS-CKP  float64
#  5   class      float64
#  6   year       int32
#  7   month      int32
#  8   day        int32
#  9   hour       int32
#  10  minute     int32
#  11  second     int32
# dtypes: float64(6), int32(6)
# memory usage: 3.4 GB

# %% [markdown]
# `Fill null values with the mean of the column except class with mode`

# %%
data['T-TPT'] = data['T-TPT'].fillna(data['T-TPT'].mean())
data['T-JUS-CKP'] = data['T-JUS-CKP'].fillna(data['T-JUS-CKP'].mean())
data['P-MON-CKP'] = data['P-MON-CKP'].fillna(data['P-MON-CKP'].mean())
data['P-TPT'] = data['P-TPT'].fillna(data['P-TPT'].mean())
data['P-PDG'] = data['P-PDG'].fillna(data['P-PDG'].mean())
mode_value = data['class'].mode()[0]
data['class'] = data['class'].fillna(mode_value)

# %%
null = pd.DataFrame({'Null Values' : data.isna().sum().sort_values(ascending=False), 'Percentage Null Values' : (data.isna().sum().sort_values(ascending=False)) / (data.shape[0]) * (100)})
null.style.background_gradient(cmap="Wistia")
# Out:
# <style type="text/css">
# #T_60bf6_row0_col0, #T_60bf6_row0_col1, #T_60bf6_row1_col0, #T_60bf6_row1_col1, #T_60bf6_row2_col0, #T_60bf6_row2_col1, #T_60bf6_row3_col0, #T_60bf6_row3_col1, #T_60bf6_row4_col0, #T_60bf6_row4_col1, #T_60bf6_row5_col0, #T_60bf6_row5_col1, #T_60bf6_row6_col0, #T_60bf6_row6_col1, #T_60bf6_row7_col0, #T_60bf6_row7_col1, #T_60bf6_row8_col0, #T_60bf6_row8_col1, #T_60bf6_row9_col0, #T_60bf6_row9_col1, #T_60bf6_row10_col0, #T_60bf6_row10_col1, #T_60bf6_row11_col0, #T_60bf6_row11_col1 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# </style>
# <table id="T_60bf6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_60bf6_level0_col0" class="col_heading level0 col0" >Null Values</th>
#       <th id="T_60bf6_level0_col1" class="col_heading level0 col1" >Percentage Null Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_60bf6_level0_row0" class="row_heading level0 row0" >P-PDG</th>
#       <td id="T_60bf6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_60bf6_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row1" class="row_heading level0 row1" >P-TPT</th>
#       <td id="T_60bf6_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_60bf6_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row2" class="row_heading level0 row2" >T-TPT</th>
#       <td id="T_60bf6_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_60bf6_row2_col1" class="data row2 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row3" class="row_heading level0 row3" >P-MON-CKP</th>
#       <td id="T_60bf6_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_60bf6_row3_col1" class="data row3 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row4" class="row_heading level0 row4" >T-JUS-CKP</th>
#       <td id="T_60bf6_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_60bf6_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row5" class="row_heading level0 row5" >class</th>
#       <td id="T_60bf6_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_60bf6_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row6" class="row_heading level0 row6" >year</th>
#       <td id="T_60bf6_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_60bf6_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row7" class="row_heading level0 row7" >month</th>
#       <td id="T_60bf6_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_60bf6_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row8" class="row_heading level0 row8" >day</th>
#       <td id="T_60bf6_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_60bf6_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row9" class="row_heading level0 row9" >hour</th>
#       <td id="T_60bf6_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_60bf6_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row10" class="row_heading level0 row10" >minute</th>
#       <td id="T_60bf6_row10_col0" class="data row10 col0" >0</td>
#       <td id="T_60bf6_row10_col1" class="data row10 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_60bf6_level0_row11" class="row_heading level0 row11" >second</th>
#       <td id="T_60bf6_row11_col0" class="data row11 col0" >0</td>
#       <td id="T_60bf6_row11_col1" class="data row11 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `Convert class , P-PDG columns to int`

# %%
data['class'] = data['class'].astype(int)
data['P-PDG'] = data['P-PDG'].astype(int)

# %% [markdown]
# `Replace values with 1 at class column to have 0 and 1`

# %%
data['class'] = data['class'].apply(lambda x: 0 if x == 0 else 1)

# %%
data.head()
# Out:
#    P-PDG       P-TPT     T-TPT  P-MON-CKP  T-JUS-CKP  class  year  month  day  \
# 0      0  10092110.0  119.0944  1609800.0   84.59782      0  2017      2    1
# 1      0  10092000.0  119.0944  1618206.0   84.58997      0  2017      2    1
# 2      0  10091890.0  119.0944  1626612.0   84.58213      0  2017      2    1
# 3      0  10091780.0  119.0944  1635018.0   84.57429      0  2017      2    1
# 4      0  10091670.0  119.0944  1643424.0   84.56644      0  2017      2    1
#
#    hour  minute  second
# 0     2       2       7
# 1     2       2       8
# 2     2       2       9
# 3     2       2      10
# 4     2       2      11

# %% [markdown]
# ## Save Data as a CSV file

# %%
data.to_csv("combined_output_cleaned_part_2.csv", index=False)
print("combined_output_cleaned_part_2 has been saved to 'combined_output_cleaned_part_2.csv'")
# Out:
# combined_output_cleaned_part_2 has been saved to 'combined_output_cleaned_part_2.csv'
